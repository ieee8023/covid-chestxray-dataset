# %% [markdown]
# ```Author: Kutsal Baran Özkurt ```

# %% [markdown]
# ### Dependecies

# %%
import os
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from tqdm import tqdm

from confusion_mat import plot_confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
from albumentations import *

from sklearn.model_selection import StratifiedKFold
from skmultilearn.model_selection import IterativeStratification

from sklearn.metrics import confusion_matrix, classification_report, precision_recall_fscore_support, accuracy_score, roc_auc_score

from keras.layers import *
from keras.callbacks import *
from keras.optimizers import *
from keras.models import load_model, Model

import tensorflow as tf
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Hyper-Parameters

# %%
SHAPE            = (224, 224, 3)
BATCH_SIZE       = 24
EPOCHS           = 100
N_SPLITS         = 3
SEED             = 1881
TRAIN_TEST_RATIO = 0.3

BASE_DIR = "../../"

# %%
metadata = pd.read_csv(os.path.join(BASE_DIR,"metadata.csv"))
metadata.head()
# Out:
#    Patientid  offset sex   age   finding survival view  date location  \
# 0          2     0.0   M  65.0  COVID-19        Y   PA  2020      NaN
# 1          2     3.0   M  65.0  COVID-19        Y   PA  2020      NaN
# 2          2     5.0   M  65.0  COVID-19        Y   PA  2020      NaN
# 3          2     6.0   M  65.0  COVID-19        Y   PA  2020      NaN
# 4          4     0.0   F   NaN  COVID-19      NaN   PA  2020      NaN
#
#                                             filename                   doi  \
# 0  auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 1  auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 2  auntminnie-c-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 3  auntminnie-d-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 4                              nejmc2001573_f1a.jpeg                   NaN
#
#                                                  url license clinical notes  \
# 0  https://www.nejm.org/doi/full/10.1056/NEJMc200...     NaN            NaN
# 1  https://www.nejm.org/doi/full/10.1056/NEJMc200...     NaN            NaN
# 2  https://www.nejm.org/doi/full/10.1056/NEJMc200...     NaN            NaN
# 3  https://www.nejm.org/doi/full/10.1056/NEJMc200...     NaN            NaN
# 4  https://www.nejm.org/doi/full/10.1056/NEJMc200...     NaN            NaN
#
#   other notes
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
metadata['finding'].hist()

# %% [markdown]
# ### Data Loader

# %%
class COVID19_DATASET:
    
    """
    metadata              --> pandas.DataFrame. refer -> https://github.com/ieee8023/covid-chestxray-dataset/blob/master/metadata.csv
    input_shape           --> TUPLE. Target image size
    batch_size            --> INT. Yielding data size for every iteration
    orders                --> LIST. Which images will be used. max=>len(all_images).
    base_dir              --> STR. Relative path of data directory.
    seed                  --> INT. This makes dataset generator more reproduciable 
    train_test_ratio      --> FLOAT. How much of data will be used as test set.
    augment               --> BOOL. Augment data or not.
    """
    
    def __init__(self, metadata, input_shape, batch_size, orders, base_dir, seed, train_test_ratio, augment=True):
        self.METADATA   = metadata          
        self.SHAPE      = input_shape
        self.BATCH_SIZE = batch_size
        self.arr        = orders
        self.SEED       = seed
        self.TT_RATIO   = train_test_ratio
        self.AUG        = augment
        
        self.BASE_DIR   = base_dir
        
        self.unique_labels, self.label_counts = self.get_unique_labels()
        
        self.hard_aug_probs = [0.5, 0.5, 0.7, 0.7]
        self.hard_aug_limits = [0.3,0.3,30]
        
        self.light_aug_probs = [0.5, 0.5, 0.3, 0.3]
        self.light_aug_limits = [0.1,0.1,10]
    
    def get_unique_labels(self):
        labels = []
        for f_name in os.listdir(os.path.join(self.BASE_DIR, "images")):
            get_data_row = self.METADATA[self.METADATA["filename"]==f_name]
            if not get_data_row.empty:
                labels.append(get_data_row['finding'].values)
        return np.unique(labels, return_counts=True)
    
    def get_paths_n_labels(self):
        paths = []
        y = []
        
        for f_name in os.listdir(os.path.join(self.BASE_DIR, "images")):
            get_data_row = self.METADATA[self.METADATA["filename"]==f_name]
            if not get_data_row.empty:
                # One-Hot Encoding
                label = np.zeros((len(self.unique_labels)))
                label_idx = np.where(get_data_row['finding'].values==self.unique_labels)[0][0]
                label[label_idx] = 1
                y.append(label)

                paths.append(os.path.join(self.BASE_DIR, "images", f_name))
            
        return paths, y
    
    def __len__(self):
        return len(self.get_paths_n_labels()[0])
    
    def augmenting(self, img, aug_probs, aug_limits):
        if self.AUG:
            augment = Compose([HorizontalFlip(p=aug_probs[0]),
                               CLAHE(p=aug_probs[1]),
                               RandomBrightnessContrast(p=aug_probs[2]),
                               ShiftScaleRotate(p=aug_probs[3], shift_limit=aug_limits[0], scale_limit=aug_limits[1], rotate_limit=aug_limits[2])])  
        else:
            augment = Compose([])  

        img = augment(image=img)['image']
        return img
    
    def get_shuffled_data(self):
        img_paths, labels = self.get_paths_n_labels()

        np.random.seed(self.SEED) 
        np.random.shuffle(img_paths)
        
        np.random.seed(self.SEED) 
        np.random.shuffle(labels)
        
        return img_paths, labels
        
    def split_train_test(self, get):  # get=={"train","test"}
        img_paths, labels = self.get_shuffled_data()
        x_train, y_train, x_test, y_test = self.iterative_train_test_split(np.array(img_paths), np.array(labels), test_size=self.TT_RATIO)
        
        if get=='train':
            return x_train, y_train
        
        elif get=='test':
            return x_test, y_test
        
    def iterative_train_test_split(self, X, y, test_size):
        """Iteratively stratified train/test split
        Parameters
        ----------
        test_size : float, [0,1]
            the proportion of the dataset to include in the test split, the rest will be put in the train set
        Returns
        -------
        X_train, y_train, X_test, y_test
            stratified division into train/test split
        """

        stratifier = IterativeStratification(n_splits=2, order=2, sample_distribution_per_fold=[test_size, 1.0-test_size])
        train_indexes, test_indexes = next(stratifier.split(y, y))
        
        X_train, y_train = X[train_indexes], y[train_indexes]
        X_test, y_test = X[test_indexes], y[test_indexes]

        return X_train, y_train, X_test, y_test

    def data_generator(self):
        img_paths, labels = self.split_train_test(get="train")
        
        while True:
            x_batch = np.empty((self.BATCH_SIZE,)+self.SHAPE, dtype=np.float32)
            y_batch = np.empty((self.BATCH_SIZE, len(self.unique_labels)), dtype=np.float32)

            batch = np.random.choice(self.arr, self.BATCH_SIZE)

            for ix, id_ in enumerate(batch):
                
                # y 
                label = labels[id_]
                
                # x
                img_path = img_paths[id_]
                img = cv2.imread(img_path)
                
                if not np.squeeze(np.where(self.unique_labels=='COVID-19'))==np.squeeze(np.where(label==max(label))):
                    img = self.augmenting(img, self.hard_aug_probs, self.hard_aug_limits)
                else:
                    img = self.augmenting(img, self.light_aug_probs, self.light_aug_limits)
                
                img = cv2.resize(img, self.SHAPE[:2])
                img = np.divide(img,255)

                # Store the values    
                x_batch[ix] = img
                y_batch[ix] = label

            yield x_batch, y_batch

# %%
sample_dataset = COVID19_DATASET(metadata, SHAPE, BATCH_SIZE, range(1), BASE_DIR, SEED, TRAIN_TEST_RATIO, augment=True)

for ix, data in enumerate(sample_dataset.data_generator()):
    img_batch, label_batch = data
    print(img_batch[0])
    print(img_batch[0].shape)
    print("-"*10)
    print(label_batch[0])
    print(label_batch[0].shape)
    print("-"*10)
    plt.imshow(img_batch[0])
    plt.show()
    
    if ix==0:
        break
# Out:
# [[[0.02352941 0.02745098 0.02745098]
#   [0.02352941 0.02745098 0.02745098]
#   [0.02352941 0.02745098 0.02745098]
#   ...
#   [0.02352941 0.02745098 0.02745098]
#   [0.02352941 0.02745098 0.02745098]
#   [0.02352941 0.02745098 0.02745098]]
#
#  [[0.02352941 0.02745098 0.02745098]
#   [0.02352941 0.02745098 0.02745098]
#   [0.02352941 0.02745098 0.02745098]
#   ...
#   [0.02352941 0.02745098 0.02745098]
#   [0.02352941 0.02745098 0.02745098]
#   [0.02352941 0.02745098 0.02745098]]
#
#  [[0.02352941 0.02745098 0.02745098]
#   [0.02352941 0.02745098 0.02745098]
#   [0.02352941 0.02745098 0.02745098]
#   ...
#   [0.02352941 0.02745098 0.02745098]
#   [0.02352941 0.02745098 0.02745098]
#   [0.02352941 0.02745098 0.02745098]]
#
#  ...
#
#  [[0.40392157 0.40392157 0.40392157]
#   [0.37254903 0.37254903 0.37254903]
#   [0.38039216 0.38039216 0.38039216]
#   ...
#   [0.01568628 0.01568628 0.01568628]
#   [0.01568628 0.01568628 0.01568628]
#   [0.01568628 0.01568628 0.01568628]]
#
#  [[0.35686275 0.35686275 0.35686275]
#   [0.3882353  0.3882353  0.3882353 ]
#   [0.29411766 0.29411766 0.29411766]
#   ...
#   [0.01960784 0.02352941 0.02352941]
#   [0.01568628 0.01568628 0.01568628]
#   [0.01568628 0.01568628 0.01568628]]
#
#  [[0.3529412  0.3529412  0.3529412 ]
#   [0.40784314 0.40784314 0.40784314]
#   [0.32156864 0.32156864 0.32156864]
#   ...
#   [0.02352941 0.02745098 0.02745098]
#   [0.01568628 0.01568628 0.01568628]
#   [0.01568628 0.01568628 0.01568628]]]
# (224, 224, 3)
# ----------
# [0. 1. 0. 0. 0. 0.]
# (6,)
# ----------

# %% [markdown]
# ### Metrics

# %%
# credits: https://stackoverflow.com/questions/43547402/how-to-calculate-f1-macro-in-keras
def recall(y_true, y_pred):
    """
    Recall metric.
    
    Only computes a batch-wise average of recall.
    
    Computes the recall, a metric for multi-label classification of
    how many relevant items are selected.
    """
    
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision(y_true, y_pred):
    """Precision metric.
    
    Only computes a batch-wise average of precision.
    
    Computes the precision, a metric for multi-label classification of
    how many selected items are relevant.
    """
    
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1(y_true, y_pred):
    precisionx = precision(y_true, y_pred)
    recallx = recall(y_true, y_pred)
    return 2*((precisionx*recallx)/(precisionx+recallx+K.epsilon()))

# %% [markdown]
# ### Learning Rate Scheduler

# %%
class SGDRScheduler(Callback):
    '''Cosine annealing learning rate scheduler with periodic restarts.
    # Usage
        ```python
            schedule = SGDRScheduler(min_lr=1e-5,
                                     max_lr=1e-2,
                                     steps_per_epoch=np.ceil(epoch_size/batch_size),
                                     lr_decay=0.9,
                                     cycle_length=5,
                                     mult_factor=1.5)
            model.fit(X_train, Y_train, epochs=100, callbacks=[schedule])
        ```
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        lr_decay: Reduce the max_lr after the completion of each cycle.
                  Ex. To reduce the max_lr by 20% after each cycle, set this value to 0.8.
        cycle_length: Initial number of epochs in a cycle.
        mult_factor: Scale epochs_to_restart after each full cycle completion.
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: http://arxiv.org/abs/1608.03983
    '''
    def __init__(self,
                 min_lr,
                 max_lr,
                 steps_per_epoch,
                 lr_decay=1,
                 cycle_length=10,
                 mult_factor=2):

        self.min_lr = min_lr
        self.max_lr = max_lr
        self.lr_decay = lr_decay

        self.batch_since_restart = 0
        self.next_restart = cycle_length

        self.steps_per_epoch = steps_per_epoch

        self.cycle_length = cycle_length
        self.mult_factor = mult_factor

        self.history = {}

    def clr(self):
        '''Calculate the learning rate.'''
        fraction_to_restart = self.batch_since_restart / (self.steps_per_epoch * self.cycle_length)
        lr = self.min_lr + 0.5 * (self.max_lr - self.min_lr) * (1 + np.cos(fraction_to_restart * np.pi))
        return lr

    def on_train_begin(self, logs={}):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.max_lr)

    def on_batch_end(self, batch, logs={}):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

        self.batch_since_restart += 1
        K.set_value(self.model.optimizer.lr, self.clr())

    def on_epoch_end(self, epoch, logs={}):
        '''Check for end of current cycle, apply restarts when necessary.'''
        if epoch + 1 == self.next_restart:
            self.batch_since_restart = 0
            self.cycle_length = np.ceil(self.cycle_length * self.mult_factor)
            self.next_restart += self.cycle_length
            self.max_lr *= self.lr_decay
            self.best_weights = self.model.get_weights()

    def on_train_end(self, logs={}):
        '''Set weights to the values from the end of the most recent cycle for best performance.'''
        self.model.set_weights(self.best_weights)

# %% [markdown]
# ## BreastNet

# %% [markdown]
# ### Citation
# ```
# M. Togaçar, K.B. Özkurt, B. Ergen et al., BreastNet: A novel ˘
# convolutional neural network model through histopathological images for the diagnosis of breast
# cancer, Physica A (2019), doi: https://doi.org/10.1016/j.physa.2019.123592.
# ```

# %%
# copied from https://github.com/kobiso/CBAM-keras/blob/master/models/attention_module.py
def cbam_block(cbam_feature, ratio=8):
    """Contains the implementation of Convolutional Block Attention Module(CBAM) block.
    As described in https://arxiv.org/abs/1807.06521.
    """
    
    cbam_feature = channel_attention(cbam_feature, ratio)
    cbam_feature = spatial_attention(cbam_feature)
    return cbam_feature

def channel_attention(input_feature, ratio=8):
    channel_axis = 1 if K.image_data_format() == "channels_first" else -1
    channel = input_feature._keras_shape[channel_axis]
    
    shared_layer_one = Dense(channel//ratio,
                             activation='relu',
                             kernel_initializer='he_normal',
                             use_bias=True,
                             bias_initializer='zeros')
    shared_layer_two = Dense(channel,
                             kernel_initializer='he_normal',
                             use_bias=True,
                             bias_initializer='zeros')
    
    avg_pool = GlobalAveragePooling2D()(input_feature)    
    avg_pool = Reshape((1,1,channel))(avg_pool)
    assert avg_pool._keras_shape[1:] == (1,1,channel)
    avg_pool = shared_layer_one(avg_pool)
    assert avg_pool._keras_shape[1:] == (1,1,channel//ratio)
    avg_pool = shared_layer_two(avg_pool)
    assert avg_pool._keras_shape[1:] == (1,1,channel)
    
    max_pool = GlobalMaxPooling2D()(input_feature)
    max_pool = Reshape((1,1,channel))(max_pool)
    assert max_pool._keras_shape[1:] == (1,1,channel)
    max_pool = shared_layer_one(max_pool)
    assert max_pool._keras_shape[1:] == (1,1,channel//ratio)
    max_pool = shared_layer_two(max_pool)
    assert max_pool._keras_shape[1:] == (1,1,channel)
    
    cbam_feature = Add()([avg_pool,max_pool])
    cbam_feature = Activation('sigmoid')(cbam_feature)

    if K.image_data_format() == "channels_first":
        cbam_feature = Permute((3, 1, 2))(cbam_feature)
    
    return multiply([input_feature, cbam_feature])

def spatial_attention(input_feature):
    kernel_size = 7
    
    if K.image_data_format() == "channels_first":
        channel = input_feature._keras_shape[1]
        cbam_feature = Permute((2,3,1))(input_feature)
    else:
        channel = input_feature._keras_shape[-1]
        cbam_feature = input_feature
    
    avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
    assert avg_pool._keras_shape[-1] == 1
    max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
    assert max_pool._keras_shape[-1] == 1
    concat = Concatenate(axis=3)([avg_pool, max_pool])
    assert concat._keras_shape[-1] == 2
    cbam_feature = Conv2D(filters = 1,
                    kernel_size=kernel_size,
                    strides=1,
                    padding='same',
                    activation='sigmoid',
                    kernel_initializer='he_normal',
                    use_bias=False)(concat)	
    assert cbam_feature._keras_shape[-1] == 1
    
    if K.image_data_format() == "channels_first":
        cbam_feature = Permute((3, 1, 2))(cbam_feature)
        
    return multiply([input_feature, cbam_feature])

# %%
# copied from https://gist.github.com/mjdietzx/5319e42637ed7ef095d430cb5c5e8c64
def residual_block(y, nb_channels, _strides=(1, 1), _project_shortcut=False):
    shortcut = y

    # down-sampling is performed with a stride of 2
    y = Conv2D(nb_channels, kernel_size=(3, 3), strides=_strides, padding='same')(y)
    y = BatchNormalization()(y)
    y = LeakyReLU()(y)

    y = Conv2D(nb_channels, kernel_size=(3, 3), strides=(1, 1), padding='same')(y)
    y = BatchNormalization()(y)

    # identity shortcuts used directly when the input and output are of the same dimensions
    if _project_shortcut or _strides != (1, 1):
        # when the dimensions increase projection shortcut is used to match dimensions (done by 1×1 convolutions)
        # when the shortcuts go across feature maps of two sizes, they are performed with a stride of 2
        shortcut = Conv2D(nb_channels, kernel_size=(1, 1), strides=_strides, padding='same')(shortcut)
        shortcut = BatchNormalization()(shortcut)

    y = add([shortcut, y])
    y = LeakyReLU()(y)

    return y

# %%
def create_model(out_neuron_number):
    
    dropRate = 0.3
    
    init = Input(SHAPE)
    x = Conv2D(32, (3, 3), activation=None, padding='same')(init) 
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(32, (3, 3), activation=None, padding='same')(x) 
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x1 = MaxPooling2D((2,2))(x)
    
    x = Conv2D(64, (3, 3), activation=None, padding='same')(x1)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = cbam_block(x)
    x = residual_block(x, 64)
    x2 = MaxPooling2D((2,2))(x)
    
    x = Conv2D(128, (3, 3), activation=None, padding='same')(x2)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = cbam_block(x)
    x = residual_block(x, 128)
    x3 = MaxPooling2D((2,2))(x)
    
    ginp1 = UpSampling2D(size=(2, 2), interpolation='bilinear')(x1)
    ginp2 = UpSampling2D(size=(4, 4), interpolation='bilinear')(x2)
    ginp3 = UpSampling2D(size=(8, 8), interpolation='bilinear')(x3)
    
    hypercolumn = Concatenate()([ginp1, ginp2, ginp3]) 
    gap = GlobalAveragePooling2D()(hypercolumn)

    x = Dense(256, activation=None)(gap)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropRate)(x)
    
    x = Dense(256, activation=None)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    y = Dense(out_neuron_number, activation='softmax')(x)
   
    model = Model(init, y)
    return model

# %%
model = create_model(len(sample_dataset.unique_labels))
model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0316 14:41:27.311947 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0316 14:41:27.313949 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0316 14:41:27.315947 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0316 14:41:27.332947 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0316 14:41:27.333945 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0316 14:41:27.334946 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0316 14:41:28.176944 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W0316 14:41:28.178947 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W0316 14:41:28.444056 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# W0316 14:41:28.455033 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0316 14:41:28.487031 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0316 14:41:28.542998 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0316 14:41:28.599034 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0316 14:41:28.943997 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:2020: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# W0316 14:41:29.007031 19208 deprecation.py:506] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 32) 9248        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 224, 224, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 224, 224, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 112, 112, 32) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 112, 112, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 112, 112, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 64)           0           activation_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 64)           0           activation_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 64)     0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 64)     0           global_max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 8)      520         reshape_1[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 64)     576         dense_1[0][0]
#                                                                  dense_1[1][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1, 1, 64)     0           dense_2[0][0]
#                                                                  dense_2[1][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 1, 64)     0           add_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 112, 112, 64) 0           activation_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 112, 112, 1)  0           multiply_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 112, 112, 1)  0           multiply_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 112, 112, 2)  0           lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 112, 112, 1)  98          concatenate_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 112, 112, 64) 0           multiply_1[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 112, 112, 64) 36928       multiply_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 112, 112, 64) 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 112, 112, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 112, 112, 64) 36928       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 112, 112, 64) 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 112, 112, 64) 0           multiply_2[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 112, 112, 64) 0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 64)   0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 128)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_2 (GlobalM (None, 128)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 128)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 128)    0           global_max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 1, 16)     2064        reshape_3[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 1, 128)    2176        dense_3[0][0]
#                                                                  dense_3[1][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1, 1, 128)    0           dense_4[0][0]
#                                                                  dense_4[1][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1, 1, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 56, 56, 128)  0           activation_5[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 56, 56, 1)    0           multiply_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 56, 56, 1)    0           multiply_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 2)    0           lambda_3[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 1)    98          concatenate_2[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 56, 56, 128)  0           multiply_3[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 128)  147584      multiply_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 56, 56, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 128)  147584      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 56, 56, 128)  0           multiply_4[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 56, 56, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 128)  0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 224, 224, 32) 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 224, 224, 64) 0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 224, 224, 128 0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 224, 224, 224 0           up_sampling2d_1[0][0]
#                                                                  up_sampling2d_2[0][0]
#                                                                  up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 224)          0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          57600       global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 256)          1024        dense_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 256)          0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           activation_7[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          65792       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 256)          1024        dense_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256)          0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 6)            1542        activation_8[0][0]
# ==================================================================================================
# Total params: 606,594
# Trainable params: 604,290
# Non-trainable params: 2,304
# __________________________________________________________________________________________________

# %% [markdown]
# ### Training

# %%
skf = StratifiedKFold(n_splits=N_SPLITS, random_state=SEED, shuffle=True)
x_t, y_t = sample_dataset.split_train_test("train")
for ix, (train_index, val_index) in enumerate(skf.split(x_t, y_t.argmax(1))):
                                               
    tg = COVID19_DATASET(metadata, SHAPE, BATCH_SIZE, train_index, BASE_DIR, SEED, TRAIN_TEST_RATIO, augment=True)
    vg = COVID19_DATASET(metadata, SHAPE, BATCH_SIZE, val_index  , BASE_DIR, SEED, TRAIN_TEST_RATIO, augment=False)
        
    schedule = SGDRScheduler(min_lr=1e-6,
                             max_lr=1e-3,
                             steps_per_epoch=np.ceil(EPOCHS/BATCH_SIZE),
                             lr_decay=0.9,
                             cycle_length=10,
                             mult_factor=2.)

    model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=1e-3), metrics=[precision, recall, f1, 'acc'])
    
    if not os.path.exists("models"):
        os.makedirs("models")
        
    model_ckpt = "models/BREASTNET_COVID19_FOLD_"+str(ix)+".h5"
    callbacks = [ModelCheckpoint(model_ckpt, monitor='val_loss', mode='min', verbose=1, save_best_only=True, save_weights_only=False),
                 TensorBoard(log_dir='./t_logs/log_'+str(ix), update_freq='batch'), 
                 schedule] 
    
    
    model.fit_generator(tg.data_generator(),
                        steps_per_epoch=len(train_index),
                        epochs=EPOCHS,
                        verbose=2,
                        validation_data=vg.data_generator(),
                        validation_steps=len(val_index)//BATCH_SIZE if len(val_index)//BATCH_SIZE else 1,
                        callbacks=callbacks)
# Out:
# W0316 06:28:27.166211  6724 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0316 06:28:27.171256  6724 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0316 06:28:27.747553  6724 deprecation.py:323] From C:\Users\pc\Anaconda3\envs\dl\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0316 06:28:28.280450  6724 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0316 06:28:28.600477  6724 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# W0316 06:28:29.602478  6724 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# W0316 06:28:29.604450  6724 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# Epoch 1/100
# W0316 06:28:36.921128  6724 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\callbacks.py:995: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#  - 98s - loss: 0.7367 - precision: 0.8166 - recall: 0.6929 - f1: 0.7287 - acc: 0.7778 - val_loss: 0.6850 - val_precision: 0.9375 - val_recall: 0.6250 - val_f1: 0.7500 - val_acc: 0.9167
#
# Epoch 00001: val_loss improved from inf to 0.68504, saving model to models/BREASTNET_COVID19_FOLD_0.h5
# Epoch 2/100
#  - 95s - loss: 0.5675 - precision: 0.8426 - recall: 0.8140 - f1: 0.8278 - acc: 0.8295 - val_loss: 2.9127 - val_precision: 0.4348 - val_recall: 0.4167 - val_f1: 0.4255 - val_acc: 0.4167
#
# Epoch 00002: val_loss did not improve from 0.68504
# Epoch 3/100
#  - 98s - loss: 0.5130 - precision: 0.8547 - recall: 0.8194 - f1: 0.8364 - acc: 0.8418 - val_loss: 1.0496 - val_precision: 0.6818 - val_recall: 0.6250 - val_f1: 0.6522 - val_acc: 0.7083
#
# Epoch 00003: val_loss did not improve from 0.68504
# Epoch 4/100
#  - 91s - loss: 0.4542 - precision: 0.8746 - recall: 0.8318 - f1: 0.8521 - acc: 0.8519 - val_loss: 0.6574 - val_precision: 0.8696 - val_recall: 0.8333 - val_f1: 0.8511 - val_acc: 0.8333
#
# Epoch 00004: val_loss improved from 0.68504 to 0.65741, saving model to models/BREASTNET_COVID19_FOLD_0.h5
# Epoch 5/100
#  - 87s - loss: 0.3295 - precision: 0.9230 - recall: 0.8727 - f1: 0.8966 - acc: 0.9028 - val_loss: 1.0558 - val_precision: 0.5714 - val_recall: 0.3333 - val_f1: 0.4211 - val_acc: 0.5417
#
# Epoch 00005: val_loss did not improve from 0.65741
# Epoch 6/100
#  - 89s - loss: 0.3691 - precision: 0.9047 - recall: 0.8704 - f1: 0.8869 - acc: 0.8873 - val_loss: 0.9576 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00006: val_loss did not improve from 0.65741
# Epoch 7/100
#  - 93s - loss: 0.2934 - precision: 0.9252 - recall: 0.8974 - f1: 0.9108 - acc: 0.9113 - val_loss: 0.7247 - val_precision: 0.8261 - val_recall: 0.7917 - val_f1: 0.8085 - val_acc: 0.7917
#
# Epoch 00007: val_loss did not improve from 0.65741
# Epoch 8/100
#  - 91s - loss: 0.3473 - precision: 0.9095 - recall: 0.8696 - f1: 0.8886 - acc: 0.8827 - val_loss: 3.5838 - val_precision: 0.1667 - val_recall: 0.1667 - val_f1: 0.1667 - val_acc: 0.1667
#
# Epoch 00008: val_loss did not improve from 0.65741
# Epoch 9/100
#  - 89s - loss: 0.2638 - precision: 0.9351 - recall: 0.9028 - f1: 0.9183 - acc: 0.9205 - val_loss: 4.2227 - val_precision: 0.1364 - val_recall: 0.1250 - val_f1: 0.1304 - val_acc: 0.1250
#
# Epoch 00009: val_loss did not improve from 0.65741
# Epoch 10/100
#  - 91s - loss: 0.2680 - precision: 0.9298 - recall: 0.8951 - f1: 0.9119 - acc: 0.9113 - val_loss: 1.6338 - val_precision: 0.6667 - val_recall: 0.6667 - val_f1: 0.6667 - val_acc: 0.6667
#
# Epoch 00010: val_loss did not improve from 0.65741
# Epoch 11/100
#  - 89s - loss: 0.2473 - precision: 0.9369 - recall: 0.9097 - f1: 0.9228 - acc: 0.9221 - val_loss: 0.4118 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00011: val_loss improved from 0.65741 to 0.41182, saving model to models/BREASTNET_COVID19_FOLD_0.h5
# Epoch 12/100
#  - 93s - loss: 0.2236 - precision: 0.9429 - recall: 0.9144 - f1: 0.9281 - acc: 0.9275 - val_loss: 2.5209 - val_precision: 0.3043 - val_recall: 0.2917 - val_f1: 0.2979 - val_acc: 0.2917
#
# Epoch 00012: val_loss did not improve from 0.41182
# Epoch 13/100
#  - 90s - loss: 0.1855 - precision: 0.9561 - recall: 0.9360 - f1: 0.9457 - acc: 0.9429 - val_loss: 2.4034 - val_precision: 0.4348 - val_recall: 0.4167 - val_f1: 0.4255 - val_acc: 0.4583
#
# Epoch 00013: val_loss did not improve from 0.41182
# Epoch 14/100
#  - 87s - loss: 0.2031 - precision: 0.9480 - recall: 0.9267 - f1: 0.9370 - acc: 0.9344 - val_loss: 2.2837 - val_precision: 0.7083 - val_recall: 0.7083 - val_f1: 0.7083 - val_acc: 0.7083
#
# Epoch 00014: val_loss did not improve from 0.41182
# Epoch 15/100
#  - 93s - loss: 0.2293 - precision: 0.9353 - recall: 0.9151 - f1: 0.9249 - acc: 0.9282 - val_loss: 1.2030 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00015: val_loss did not improve from 0.41182
# Epoch 16/100
#  - 96s - loss: 0.1793 - precision: 0.9558 - recall: 0.9360 - f1: 0.9456 - acc: 0.9460 - val_loss: 2.6002 - val_precision: 0.7083 - val_recall: 0.7083 - val_f1: 0.7083 - val_acc: 0.7083
#
# Epoch 00016: val_loss did not improve from 0.41182
# Epoch 17/100
#  - 88s - loss: 0.1510 - precision: 0.9661 - recall: 0.9491 - f1: 0.9573 - acc: 0.9560 - val_loss: 1.1100 - val_precision: 0.7826 - val_recall: 0.7500 - val_f1: 0.7660 - val_acc: 0.7500
#
# Epoch 00017: val_loss did not improve from 0.41182
# Epoch 18/100
#  - 92s - loss: 0.1958 - precision: 0.9494 - recall: 0.9259 - f1: 0.9373 - acc: 0.9367 - val_loss: 1.0826 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00018: val_loss did not improve from 0.41182
# Epoch 19/100
#  - 93s - loss: 0.2019 - precision: 0.9528 - recall: 0.9275 - f1: 0.9397 - acc: 0.9429 - val_loss: 1.8548 - val_precision: 0.6250 - val_recall: 0.6250 - val_f1: 0.6250 - val_acc: 0.6250
#
# Epoch 00019: val_loss did not improve from 0.41182
# Epoch 20/100
#  - 90s - loss: 0.1345 - precision: 0.9702 - recall: 0.9460 - f1: 0.9576 - acc: 0.9568 - val_loss: 1.6669 - val_precision: 0.5833 - val_recall: 0.5833 - val_f1: 0.5833 - val_acc: 0.5833
#
# Epoch 00020: val_loss did not improve from 0.41182
# Epoch 21/100
#  - 92s - loss: 0.1680 - precision: 0.9658 - recall: 0.9452 - f1: 0.9552 - acc: 0.9529 - val_loss: 3.3021 - val_precision: 0.3043 - val_recall: 0.2917 - val_f1: 0.2979 - val_acc: 0.2917
#
# Epoch 00021: val_loss did not improve from 0.41182
# Epoch 22/100
#  - 98s - loss: 0.2089 - precision: 0.9469 - recall: 0.9205 - f1: 0.9332 - acc: 0.9336 - val_loss: 1.1904 - val_precision: 0.7500 - val_recall: 0.6250 - val_f1: 0.6818 - val_acc: 0.6250
#
# Epoch 00022: val_loss did not improve from 0.41182
# Epoch 23/100
#  - 98s - loss: 0.1596 - precision: 0.9601 - recall: 0.9421 - f1: 0.9509 - acc: 0.9514 - val_loss: 0.1947 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00023: val_loss improved from 0.41182 to 0.19472, saving model to models/BREASTNET_COVID19_FOLD_0.h5
# Epoch 24/100
#  - 93s - loss: 0.1457 - precision: 0.9644 - recall: 0.9468 - f1: 0.9552 - acc: 0.9583 - val_loss: 3.1003 - val_precision: 0.2381 - val_recall: 0.2083 - val_f1: 0.2222 - val_acc: 0.2083
#
# Epoch 00024: val_loss did not improve from 0.19472
# Epoch 25/100
#  - 97s - loss: 0.1467 - precision: 0.9665 - recall: 0.9545 - f1: 0.9603 - acc: 0.9568 - val_loss: 11.4354 - val_precision: 0.0417 - val_recall: 0.0417 - val_f1: 0.0417 - val_acc: 0.0417
#
# Epoch 00025: val_loss did not improve from 0.19472
# Epoch 26/100
#  - 97s - loss: 0.1753 - precision: 0.9526 - recall: 0.9329 - f1: 0.9425 - acc: 0.9414 - val_loss: 1.1749 - val_precision: 0.5833 - val_recall: 0.5833 - val_f1: 0.5833 - val_acc: 0.5833
#
# Epoch 00026: val_loss did not improve from 0.19472
# Epoch 27/100
#  - 97s - loss: 0.1146 - precision: 0.9683 - recall: 0.9475 - f1: 0.9576 - acc: 0.9583 - val_loss: 1.3836 - val_precision: 0.5909 - val_recall: 0.5417 - val_f1: 0.5652 - val_acc: 0.5417
#
# Epoch 00027: val_loss did not improve from 0.19472
# Epoch 28/100
#  - 98s - loss: 0.1154 - precision: 0.9712 - recall: 0.9568 - f1: 0.9637 - acc: 0.9645 - val_loss: 2.8604 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00028: val_loss did not improve from 0.19472
# Epoch 29/100
#  - 96s - loss: 0.1594 - precision: 0.9577 - recall: 0.9460 - f1: 0.9517 - acc: 0.9514 - val_loss: 1.3018 - val_precision: 0.6818 - val_recall: 0.6250 - val_f1: 0.6522 - val_acc: 0.7083
#
# Epoch 00029: val_loss did not improve from 0.19472
# Epoch 30/100
#  - 90s - loss: 0.1440 - precision: 0.9561 - recall: 0.9429 - f1: 0.9494 - acc: 0.9483 - val_loss: 1.2942 - val_precision: 0.6667 - val_recall: 0.6667 - val_f1: 0.6667 - val_acc: 0.6667
#
# Epoch 00030: val_loss did not improve from 0.19472
# Epoch 31/100
#  - 91s - loss: 0.1226 - precision: 0.9653 - recall: 0.9514 - f1: 0.9582 - acc: 0.9568 - val_loss: 3.4940 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00031: val_loss did not improve from 0.19472
# Epoch 32/100
#  - 91s - loss: 0.1603 - precision: 0.9521 - recall: 0.9375 - f1: 0.9446 - acc: 0.9460 - val_loss: 1.3252 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00032: val_loss did not improve from 0.19472
# Epoch 33/100
#  - 93s - loss: 0.0864 - precision: 0.9767 - recall: 0.9630 - f1: 0.9696 - acc: 0.9676 - val_loss: 0.9503 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00033: val_loss did not improve from 0.19472
# Epoch 34/100
#  - 87s - loss: 0.0795 - precision: 0.9804 - recall: 0.9707 - f1: 0.9754 - acc: 0.9753 - val_loss: 0.5626 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00034: val_loss did not improve from 0.19472
# Epoch 35/100
#  - 94s - loss: 0.0636 - precision: 0.9852 - recall: 0.9753 - f1: 0.9801 - acc: 0.9784 - val_loss: 0.5083 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00035: val_loss did not improve from 0.19472
# Epoch 36/100
#  - 90s - loss: 0.0991 - precision: 0.9743 - recall: 0.9591 - f1: 0.9665 - acc: 0.9684 - val_loss: 1.0657 - val_precision: 0.6667 - val_recall: 0.6667 - val_f1: 0.6667 - val_acc: 0.6667
#
# Epoch 00036: val_loss did not improve from 0.19472
# Epoch 37/100
#  - 90s - loss: 0.1240 - precision: 0.9695 - recall: 0.9591 - f1: 0.9642 - acc: 0.9630 - val_loss: 2.6968 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00037: val_loss did not improve from 0.19472
# Epoch 38/100
#  - 94s - loss: 0.1408 - precision: 0.9603 - recall: 0.9498 - f1: 0.9550 - acc: 0.9552 - val_loss: 4.0106 - val_precision: 0.3750 - val_recall: 0.3750 - val_f1: 0.3750 - val_acc: 0.3750
#
# Epoch 00038: val_loss did not improve from 0.19472
# Epoch 39/100
#  - 90s - loss: 0.1352 - precision: 0.9580 - recall: 0.9483 - f1: 0.9531 - acc: 0.9537 - val_loss: 1.9199 - val_precision: 0.4737 - val_recall: 0.3750 - val_f1: 0.4186 - val_acc: 0.5417
#
# Epoch 00039: val_loss did not improve from 0.19472
# Epoch 40/100
#  - 91s - loss: 0.1014 - precision: 0.9721 - recall: 0.9653 - f1: 0.9686 - acc: 0.9691 - val_loss: 4.1216 - val_precision: 0.2174 - val_recall: 0.2083 - val_f1: 0.2128 - val_acc: 0.2083
#
# Epoch 00040: val_loss did not improve from 0.19472
# Epoch 41/100
#  - 89s - loss: 0.0652 - precision: 0.9814 - recall: 0.9761 - f1: 0.9786 - acc: 0.9784 - val_loss: 1.3702 - val_precision: 0.6957 - val_recall: 0.6667 - val_f1: 0.6809 - val_acc: 0.6667
#
# Epoch 00041: val_loss did not improve from 0.19472
# Epoch 42/100
#  - 89s - loss: 0.0641 - precision: 0.9829 - recall: 0.9792 - f1: 0.9810 - acc: 0.9815 - val_loss: 1.3923 - val_precision: 0.6250 - val_recall: 0.6250 - val_f1: 0.6250 - val_acc: 0.6250
#
# Epoch 00042: val_loss did not improve from 0.19472
# Epoch 43/100
#  - 89s - loss: 0.0912 - precision: 0.9812 - recall: 0.9730 - f1: 0.9770 - acc: 0.9753 - val_loss: 0.9870 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00043: val_loss did not improve from 0.19472
# Epoch 44/100
#  - 99s - loss: 0.1425 - precision: 0.9631 - recall: 0.9537 - f1: 0.9583 - acc: 0.9568 - val_loss: 1.0432 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00044: val_loss did not improve from 0.19472
# Epoch 45/100
#  - 91s - loss: 0.1101 - precision: 0.9726 - recall: 0.9614 - f1: 0.9669 - acc: 0.9676 - val_loss: 2.3999 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00045: val_loss did not improve from 0.19472
# Epoch 46/100
#  - 91s - loss: 0.1124 - precision: 0.9681 - recall: 0.9614 - f1: 0.9647 - acc: 0.9637 - val_loss: 0.3561 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00046: val_loss did not improve from 0.19472
# Epoch 47/100
#  - 99s - loss: 0.0914 - precision: 0.9712 - recall: 0.9660 - f1: 0.9686 - acc: 0.9676 - val_loss: 2.0806 - val_precision: 0.6667 - val_recall: 0.6667 - val_f1: 0.6667 - val_acc: 0.6667
#
# Epoch 00047: val_loss did not improve from 0.19472
# Epoch 48/100
#  - 92s - loss: 0.0763 - precision: 0.9791 - recall: 0.9753 - f1: 0.9771 - acc: 0.9761 - val_loss: 1.9015 - val_precision: 0.7083 - val_recall: 0.7083 - val_f1: 0.7083 - val_acc: 0.7083
#
# Epoch 00048: val_loss did not improve from 0.19472
# Epoch 49/100
#  - 88s - loss: 0.0500 - precision: 0.9891 - recall: 0.9861 - f1: 0.9876 - acc: 0.9877 - val_loss: 1.3692 - val_precision: 0.6667 - val_recall: 0.6667 - val_f1: 0.6667 - val_acc: 0.6667
#
# Epoch 00049: val_loss did not improve from 0.19472
# Epoch 50/100
#  - 89s - loss: 0.0641 - precision: 0.9845 - recall: 0.9815 - f1: 0.9830 - acc: 0.9838 - val_loss: 3.1763 - val_precision: 0.2778 - val_recall: 0.2083 - val_f1: 0.2381 - val_acc: 0.2500
#
# Epoch 00050: val_loss did not improve from 0.19472
# Epoch 51/100
#  - 88s - loss: 0.0569 - precision: 0.9845 - recall: 0.9792 - f1: 0.9818 - acc: 0.9823 - val_loss: 0.6106 - val_precision: 0.8696 - val_recall: 0.8333 - val_f1: 0.8511 - val_acc: 0.8333
#
# Epoch 00051: val_loss did not improve from 0.19472
# Epoch 52/100
#  - 93s - loss: 0.0877 - precision: 0.9744 - recall: 0.9699 - f1: 0.9721 - acc: 0.9738 - val_loss: 4.0604 - val_precision: 0.2917 - val_recall: 0.2917 - val_f1: 0.2917 - val_acc: 0.2917
#
# Epoch 00052: val_loss did not improve from 0.19472
# Epoch 53/100
#  - 93s - loss: 0.1029 - precision: 0.9730 - recall: 0.9668 - f1: 0.9698 - acc: 0.9699 - val_loss: 0.5884 - val_precision: 0.9130 - val_recall: 0.8750 - val_f1: 0.8936 - val_acc: 0.9167
#
# Epoch 00053: val_loss did not improve from 0.19472
# Epoch 54/100
#  - 95s - loss: 0.1129 - precision: 0.9689 - recall: 0.9630 - f1: 0.9659 - acc: 0.9660 - val_loss: 0.9632 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00054: val_loss did not improve from 0.19472
# Epoch 55/100
#  - 94s - loss: 0.0979 - precision: 0.9767 - recall: 0.9715 - f1: 0.9740 - acc: 0.9730 - val_loss: 0.3486 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00055: val_loss did not improve from 0.19472
# Epoch 56/100
#  - 92s - loss: 0.0700 - precision: 0.9830 - recall: 0.9807 - f1: 0.9818 - acc: 0.9823 - val_loss: 0.5361 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00056: val_loss did not improve from 0.19472
# Epoch 57/100
#  - 91s - loss: 0.0678 - precision: 0.9813 - recall: 0.9784 - f1: 0.9798 - acc: 0.9799 - val_loss: 0.4479 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00057: val_loss did not improve from 0.19472
# Epoch 58/100
#  - 99s - loss: 0.0588 - precision: 0.9852 - recall: 0.9799 - f1: 0.9825 - acc: 0.9823 - val_loss: 3.1066 - val_precision: 0.3750 - val_recall: 0.3750 - val_f1: 0.3750 - val_acc: 0.3750
#
# Epoch 00058: val_loss did not improve from 0.19472
# Epoch 59/100
#  - 91s - loss: 0.0740 - precision: 0.9807 - recall: 0.9769 - f1: 0.9787 - acc: 0.9776 - val_loss: 0.3292 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00059: val_loss did not improve from 0.19472
# Epoch 60/100
#  - 93s - loss: 0.1216 - precision: 0.9656 - recall: 0.9537 - f1: 0.9595 - acc: 0.9568 - val_loss: 7.6725 - val_precision: 0.0870 - val_recall: 0.0833 - val_f1: 0.0851 - val_acc: 0.0833
#
# Epoch 00060: val_loss did not improve from 0.19472
# Epoch 61/100
#  - 93s - loss: 0.1351 - precision: 0.9603 - recall: 0.9475 - f1: 0.9537 - acc: 0.9560 - val_loss: 0.9684 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00061: val_loss did not improve from 0.19472
# Epoch 62/100
#  - 94s - loss: 0.0828 - precision: 0.9812 - recall: 0.9722 - f1: 0.9766 - acc: 0.9745 - val_loss: 2.5804 - val_precision: 0.3750 - val_recall: 0.3750 - val_f1: 0.3750 - val_acc: 0.3750
#
# Epoch 00062: val_loss did not improve from 0.19472
# Epoch 63/100
#  - 97s - loss: 0.0669 - precision: 0.9837 - recall: 0.9745 - f1: 0.9790 - acc: 0.9799 - val_loss: 1.5720 - val_precision: 0.5455 - val_recall: 0.5000 - val_f1: 0.5217 - val_acc: 0.5000
#
# Epoch 00063: val_loss did not improve from 0.19472
# Epoch 64/100
#  - 89s - loss: 0.0503 - precision: 0.9876 - recall: 0.9823 - f1: 0.9848 - acc: 0.9853 - val_loss: 1.2781 - val_precision: 0.6957 - val_recall: 0.6667 - val_f1: 0.6809 - val_acc: 0.7083
#
# Epoch 00064: val_loss did not improve from 0.19472
# Epoch 65/100
#  - 97s - loss: 0.0701 - precision: 0.9837 - recall: 0.9815 - f1: 0.9826 - acc: 0.9823 - val_loss: 1.9017 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
# Epoch 00065: val_loss did not improve from 0.19472
# Epoch 66/100
#  - 98s - loss: 0.0517 - precision: 0.9868 - recall: 0.9838 - f1: 0.9853 - acc: 0.9853 - val_loss: 0.9148 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00066: val_loss did not improve from 0.19472
# Epoch 67/100
#  - 94s - loss: 0.0755 - precision: 0.9814 - recall: 0.9792 - f1: 0.9803 - acc: 0.9807 - val_loss: 2.2968 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00067: val_loss did not improve from 0.19472
# Epoch 68/100
#  - 94s - loss: 0.1034 - precision: 0.9705 - recall: 0.9637 - f1: 0.9670 - acc: 0.9676 - val_loss: 2.7977 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00068: val_loss did not improve from 0.19472
# Epoch 69/100
#  - 92s - loss: 0.0950 - precision: 0.9733 - recall: 0.9637 - f1: 0.9684 - acc: 0.9691 - val_loss: 0.2295 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00069: val_loss did not improve from 0.19472
# Epoch 70/100
#  - 89s - loss: 0.0653 - precision: 0.9823 - recall: 0.9769 - f1: 0.9795 - acc: 0.9807 - val_loss: 1.0197 - val_precision: 0.5652 - val_recall: 0.5417 - val_f1: 0.5532 - val_acc: 0.5417
#
# Epoch 00070: val_loss did not improve from 0.19472
# Epoch 71/100
#  - 94s - loss: 0.0822 - precision: 0.9776 - recall: 0.9753 - f1: 0.9764 - acc: 0.9761 - val_loss: 1.3390 - val_precision: 0.7083 - val_recall: 0.7083 - val_f1: 0.7083 - val_acc: 0.7083
#
# Epoch 00071: val_loss did not improve from 0.19472
# Epoch 72/100
#  - 97s - loss: 0.0878 - precision: 0.9760 - recall: 0.9722 - f1: 0.9741 - acc: 0.9738 - val_loss: 2.2089 - val_precision: 0.5833 - val_recall: 0.5833 - val_f1: 0.5833 - val_acc: 0.5833
#
# Epoch 00072: val_loss did not improve from 0.19472
# Epoch 73/100
#  - 91s - loss: 0.0715 - precision: 0.9782 - recall: 0.9707 - f1: 0.9744 - acc: 0.9738 - val_loss: 2.9835 - val_precision: 0.4348 - val_recall: 0.4167 - val_f1: 0.4255 - val_acc: 0.4167
#
# Epoch 00073: val_loss did not improve from 0.19472
# Epoch 74/100
#  - 96s - loss: 0.0508 - precision: 0.9830 - recall: 0.9807 - f1: 0.9818 - acc: 0.9823 - val_loss: 6.4052 - val_precision: 0.1667 - val_recall: 0.1667 - val_f1: 0.1667 - val_acc: 0.1667
#
# Epoch 00074: val_loss did not improve from 0.19472
# Epoch 75/100
#  - 93s - loss: 0.0521 - precision: 0.9876 - recall: 0.9784 - f1: 0.9829 - acc: 0.9830 - val_loss: 0.8015 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00075: val_loss did not improve from 0.19472
# Epoch 76/100
#  - 87s - loss: 0.0469 - precision: 0.9884 - recall: 0.9869 - f1: 0.9876 - acc: 0.9869 - val_loss: 0.4289 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00076: val_loss did not improve from 0.19472
# Epoch 77/100
#  - 93s - loss: 0.0419 - precision: 0.9923 - recall: 0.9877 - f1: 0.9899 - acc: 0.9877 - val_loss: 0.5463 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00077: val_loss did not improve from 0.19472
# Epoch 78/100
#  - 91s - loss: 0.0410 - precision: 0.9923 - recall: 0.9923 - f1: 0.9923 - acc: 0.9923 - val_loss: 0.4203 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00078: val_loss did not improve from 0.19472
# Epoch 79/100
#  - 91s - loss: 0.0282 - precision: 0.9930 - recall: 0.9892 - f1: 0.9911 - acc: 0.9900 - val_loss: 0.5065 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00079: val_loss did not improve from 0.19472
# Epoch 80/100
#  - 95s - loss: 0.0415 - precision: 0.9884 - recall: 0.9877 - f1: 0.9880 - acc: 0.9884 - val_loss: 0.1230 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00080: val_loss improved from 0.19472 to 0.12302, saving model to models/BREASTNET_COVID19_FOLD_0.h5
# Epoch 81/100
#  - 94s - loss: 0.0524 - precision: 0.9852 - recall: 0.9784 - f1: 0.9817 - acc: 0.9815 - val_loss: 1.7535 - val_precision: 0.7083 - val_recall: 0.7083 - val_f1: 0.7083 - val_acc: 0.7083
#
# Epoch 00081: val_loss did not improve from 0.12302
# Epoch 82/100
#  - 92s - loss: 0.0357 - precision: 0.9892 - recall: 0.9853 - f1: 0.9872 - acc: 0.9877 - val_loss: 2.5315 - val_precision: 0.8182 - val_recall: 0.7500 - val_f1: 0.7826 - val_acc: 0.8333
#
# Epoch 00082: val_loss did not improve from 0.12302
# Epoch 83/100
#  - 92s - loss: 0.0804 - precision: 0.9783 - recall: 0.9722 - f1: 0.9752 - acc: 0.9753 - val_loss: 1.7042 - val_precision: 0.6957 - val_recall: 0.6667 - val_f1: 0.6809 - val_acc: 0.7083
#
# Epoch 00083: val_loss did not improve from 0.12302
# Epoch 84/100
#  - 95s - loss: 0.0828 - precision: 0.9760 - recall: 0.9745 - f1: 0.9753 - acc: 0.9753 - val_loss: 1.3978 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00084: val_loss did not improve from 0.12302
# Epoch 85/100
#  - 89s - loss: 0.0784 - precision: 0.9768 - recall: 0.9691 - f1: 0.9729 - acc: 0.9722 - val_loss: 2.7377 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00085: val_loss did not improve from 0.12302
# Epoch 86/100
#  - 94s - loss: 0.1048 - precision: 0.9720 - recall: 0.9653 - f1: 0.9686 - acc: 0.9676 - val_loss: 1.9385 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00086: val_loss did not improve from 0.12302
# Epoch 87/100
#  - 97s - loss: 0.0971 - precision: 0.9712 - recall: 0.9645 - f1: 0.9678 - acc: 0.9684 - val_loss: 2.3685 - val_precision: 0.5000 - val_recall: 0.5000 - val_f1: 0.5000 - val_acc: 0.5000
#
# Epoch 00087: val_loss did not improve from 0.12302
# Epoch 88/100
#  - 96s - loss: 0.0660 - precision: 0.9784 - recall: 0.9761 - f1: 0.9772 - acc: 0.9776 - val_loss: 2.2488 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00088: val_loss did not improve from 0.12302
# Epoch 89/100
#  - 96s - loss: 0.0418 - precision: 0.9876 - recall: 0.9853 - f1: 0.9864 - acc: 0.9861 - val_loss: 1.4576 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00089: val_loss did not improve from 0.12302
# Epoch 90/100
#  - 94s - loss: 0.0385 - precision: 0.9907 - recall: 0.9892 - f1: 0.9900 - acc: 0.9900 - val_loss: 0.9998 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00090: val_loss did not improve from 0.12302
# Epoch 91/100
#  - 93s - loss: 0.0263 - precision: 0.9931 - recall: 0.9931 - f1: 0.9931 - acc: 0.9931 - val_loss: 1.6327 - val_precision: 0.6667 - val_recall: 0.6667 - val_f1: 0.6667 - val_acc: 0.6667
#
# Epoch 00091: val_loss did not improve from 0.12302
# Epoch 92/100
#  - 102s - loss: 0.0415 - precision: 0.9877 - recall: 0.9853 - f1: 0.9865 - acc: 0.9869 - val_loss: 2.1076 - val_precision: 0.5000 - val_recall: 0.5000 - val_f1: 0.5000 - val_acc: 0.5000
#
# Epoch 00092: val_loss did not improve from 0.12302
# Epoch 93/100
#  - 86s - loss: 0.0311 - precision: 0.9931 - recall: 0.9907 - f1: 0.9919 - acc: 0.9923 - val_loss: 1.6028 - val_precision: 0.5833 - val_recall: 0.5833 - val_f1: 0.5833 - val_acc: 0.5833
#
# Epoch 00093: val_loss did not improve from 0.12302
# Epoch 94/100
#  - 93s - loss: 0.0306 - precision: 0.9938 - recall: 0.9915 - f1: 0.9926 - acc: 0.9931 - val_loss: 0.9026 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00094: val_loss did not improve from 0.12302
# Epoch 95/100
#  - 96s - loss: 0.0336 - precision: 0.9907 - recall: 0.9900 - f1: 0.9903 - acc: 0.9900 - val_loss: 0.5941 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00095: val_loss did not improve from 0.12302
# Epoch 96/100
#  - 97s - loss: 0.0552 - precision: 0.9861 - recall: 0.9853 - f1: 0.9857 - acc: 0.9861 - val_loss: 1.8903 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00096: val_loss did not improve from 0.12302
# Epoch 97/100
#  - 100s - loss: 0.0566 - precision: 0.9852 - recall: 0.9823 - f1: 0.9837 - acc: 0.9830 - val_loss: 1.7090 - val_precision: 0.7083 - val_recall: 0.7083 - val_f1: 0.7083 - val_acc: 0.7083
#
# Epoch 00097: val_loss did not improve from 0.12302
# Epoch 98/100
#  - 96s - loss: 0.0494 - precision: 0.9852 - recall: 0.9799 - f1: 0.9825 - acc: 0.9807 - val_loss: 1.4867 - val_precision: 0.6957 - val_recall: 0.6667 - val_f1: 0.6809 - val_acc: 0.7083
# Epoch 00098: val_loss did not improve from 0.12302
# Epoch 99/100
#  - 97s - loss: 0.0487 - precision: 0.9869 - recall: 0.9838 - f1: 0.9853 - acc: 0.9846 - val_loss: 2.5556 - val_precision: 0.5833 - val_recall: 0.5833 - val_f1: 0.5833 - val_acc: 0.5833
#
# Epoch 00099: val_loss did not improve from 0.12302
# Epoch 100/100
#  - 99s - loss: 0.0674 - precision: 0.9791 - recall: 0.9738 - f1: 0.9764 - acc: 0.9761 - val_loss: 9.5263 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1: 0.0000e+00 - val_acc: 0.0000e+00
#
# Epoch 00100: val_loss did not improve from 0.12302
# Epoch 1/100
#  - 84s - loss: 0.3130 - precision: 0.9137 - recall: 0.8935 - f1: 0.9033 - acc: 0.9005 - val_loss: 1.1798 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00001: val_loss improved from inf to 1.17983, saving model to models/BREASTNET_COVID19_FOLD_1.h5
# Epoch 2/100
#  - 85s - loss: 0.1951 - precision: 0.9426 - recall: 0.9213 - f1: 0.9316 - acc: 0.9298 - val_loss: 0.1710 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00002: val_loss improved from 1.17983 to 0.17103, saving model to models/BREASTNET_COVID19_FOLD_1.h5
# Epoch 3/100
#  - 88s - loss: 0.1938 - precision: 0.9454 - recall: 0.9182 - f1: 0.9313 - acc: 0.9313 - val_loss: 0.3820 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00003: val_loss did not improve from 0.17103
# Epoch 4/100
#  - 87s - loss: 0.1673 - precision: 0.9511 - recall: 0.9298 - f1: 0.9401 - acc: 0.9437 - val_loss: 2.0102 - val_precision: 0.3636 - val_recall: 0.3333 - val_f1: 0.3478 - val_acc: 0.3750
#
# Epoch 00004: val_loss did not improve from 0.17103
# Epoch 5/100
#  - 93s - loss: 0.1320 - precision: 0.9615 - recall: 0.9429 - f1: 0.9519 - acc: 0.9537 - val_loss: 0.3666 - val_precision: 0.8696 - val_recall: 0.8333 - val_f1: 0.8511 - val_acc: 0.8750
#
# Epoch 00005: val_loss did not improve from 0.17103
# Epoch 6/100
#  - 89s - loss: 0.1222 - precision: 0.9671 - recall: 0.9545 - f1: 0.9606 - acc: 0.9591 - val_loss: 0.8972 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00006: val_loss did not improve from 0.17103
# Epoch 7/100
#  - 92s - loss: 0.1241 - precision: 0.9687 - recall: 0.9522 - f1: 0.9602 - acc: 0.9560 - val_loss: 1.6438 - val_precision: 0.5417 - val_recall: 0.5417 - val_f1: 0.5417 - val_acc: 0.5417
#
# Epoch 00007: val_loss did not improve from 0.17103
# Epoch 8/100
#  - 92s - loss: 0.1393 - precision: 0.9571 - recall: 0.9468 - f1: 0.9517 - acc: 0.9506 - val_loss: 0.9140 - val_precision: 0.7826 - val_recall: 0.7500 - val_f1: 0.7660 - val_acc: 0.7500
#
# Epoch 00008: val_loss did not improve from 0.17103
# Epoch 9/100
#  - 93s - loss: 0.1144 - precision: 0.9707 - recall: 0.9506 - f1: 0.9604 - acc: 0.9599 - val_loss: 0.4772 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00009: val_loss did not improve from 0.17103
# Epoch 10/100
#  - 85s - loss: 0.0914 - precision: 0.9726 - recall: 0.9630 - f1: 0.9677 - acc: 0.9653 - val_loss: 0.7102 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00010: val_loss did not improve from 0.17103
# Epoch 11/100
#  - 88s - loss: 0.0692 - precision: 0.9845 - recall: 0.9722 - f1: 0.9782 - acc: 0.9784 - val_loss: 0.0064 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00011: val_loss improved from 0.17103 to 0.00641, saving model to models/BREASTNET_COVID19_FOLD_1.h5
# Epoch 12/100
#  - 88s - loss: 0.0757 - precision: 0.9744 - recall: 0.9707 - f1: 0.9725 - acc: 0.9738 - val_loss: 0.1731 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00012: val_loss did not improve from 0.00641
# Epoch 13/100
#  - 95s - loss: 0.0603 - precision: 0.9837 - recall: 0.9807 - f1: 0.9822 - acc: 0.9838 - val_loss: 0.7115 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00013: val_loss did not improve from 0.00641
# Epoch 14/100
#  - 90s - loss: 0.1065 - precision: 0.9681 - recall: 0.9614 - f1: 0.9647 - acc: 0.9645 - val_loss: 3.8363 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00014: val_loss did not improve from 0.00641
# Epoch 15/100
#  - 89s - loss: 0.1002 - precision: 0.9721 - recall: 0.9606 - f1: 0.9661 - acc: 0.9668 - val_loss: 0.3092 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00015: val_loss did not improve from 0.00641
# Epoch 16/100
#  - 90s - loss: 0.0562 - precision: 0.9867 - recall: 0.9776 - f1: 0.9820 - acc: 0.9799 - val_loss: 0.5296 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00016: val_loss did not improve from 0.00641
# Epoch 17/100
#  - 89s - loss: 0.0460 - precision: 0.9875 - recall: 0.9830 - f1: 0.9852 - acc: 0.9869 - val_loss: 0.2673 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00017: val_loss did not improve from 0.00641
# Epoch 18/100
#  - 90s - loss: 0.0990 - precision: 0.9721 - recall: 0.9660 - f1: 0.9690 - acc: 0.9699 - val_loss: 0.3525 - val_precision: 0.9500 - val_recall: 0.7917 - val_f1: 0.8636 - val_acc: 0.8750
#
# Epoch 00018: val_loss did not improve from 0.00641
# Epoch 19/100
#  - 92s - loss: 0.0731 - precision: 0.9791 - recall: 0.9761 - f1: 0.9776 - acc: 0.9769 - val_loss: 0.0464 - val_precision: 1.0000 - val_recall: 0.9583 - val_f1: 0.9787 - val_acc: 1.0000
#
# Epoch 00019: val_loss did not improve from 0.00641
# Epoch 20/100
#  - 92s - loss: 0.0518 - precision: 0.9852 - recall: 0.9784 - f1: 0.9817 - acc: 0.9823 - val_loss: 0.0929 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00020: val_loss did not improve from 0.00641
# Epoch 21/100
#  - 89s - loss: 0.0927 - precision: 0.9674 - recall: 0.9637 - f1: 0.9655 - acc: 0.9637 - val_loss: 0.2947 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00021: val_loss did not improve from 0.00641
# Epoch 22/100
#  - 86s - loss: 0.0940 - precision: 0.9704 - recall: 0.9653 - f1: 0.9678 - acc: 0.9668 - val_loss: 1.9343 - val_precision: 0.6957 - val_recall: 0.6667 - val_f1: 0.6809 - val_acc: 0.6667
#
# Epoch 00022: val_loss did not improve from 0.00641
# Epoch 23/100
#  - 89s - loss: 0.0597 - precision: 0.9822 - recall: 0.9761 - f1: 0.9790 - acc: 0.9769 - val_loss: 0.0928 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00023: val_loss did not improve from 0.00641
# Epoch 24/100
#  - 90s - loss: 0.0580 - precision: 0.9791 - recall: 0.9761 - f1: 0.9776 - acc: 0.9776 - val_loss: 0.4404 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00024: val_loss did not improve from 0.00641
# Epoch 25/100
#  - 87s - loss: 0.0595 - precision: 0.9829 - recall: 0.9761 - f1: 0.9794 - acc: 0.9799 - val_loss: 1.1981 - val_precision: 0.6818 - val_recall: 0.6250 - val_f1: 0.6522 - val_acc: 0.6250
#
# Epoch 00025: val_loss did not improve from 0.00641
# Epoch 26/100
#  - 94s - loss: 0.0804 - precision: 0.9776 - recall: 0.9753 - f1: 0.9764 - acc: 0.9761 - val_loss: 0.3012 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00026: val_loss did not improve from 0.00641
# Epoch 27/100
#  - 93s - loss: 0.0552 - precision: 0.9830 - recall: 0.9776 - f1: 0.9802 - acc: 0.9792 - val_loss: 0.2342 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00027: val_loss did not improve from 0.00641
# Epoch 28/100
#  - 98s - loss: 0.0341 - precision: 0.9907 - recall: 0.9892 - f1: 0.9899 - acc: 0.9907 - val_loss: 0.9150 - val_precision: 0.8261 - val_recall: 0.7917 - val_f1: 0.8085 - val_acc: 0.7917
#
# Epoch 00028: val_loss did not improve from 0.00641
# Epoch 29/100
#  - 85s - loss: 0.0664 - precision: 0.9769 - recall: 0.9745 - f1: 0.9757 - acc: 0.9761 - val_loss: 1.7504 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00029: val_loss did not improve from 0.00641
# Epoch 30/100
#  - 91s - loss: 0.0705 - precision: 0.9790 - recall: 0.9730 - f1: 0.9759 - acc: 0.9753 - val_loss: 1.0858 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00030: val_loss did not improve from 0.00641
# Epoch 31/100
#  - 87s - loss: 0.0730 - precision: 0.9790 - recall: 0.9745 - f1: 0.9767 - acc: 0.9769 - val_loss: 2.5368 - val_precision: 0.3750 - val_recall: 0.3750 - val_f1: 0.3750 - val_acc: 0.3750
#
# Epoch 00031: val_loss did not improve from 0.00641
# Epoch 32/100
#  - 94s - loss: 0.0689 - precision: 0.9822 - recall: 0.9761 - f1: 0.9791 - acc: 0.9792 - val_loss: 1.6584 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00032: val_loss did not improve from 0.00641
# Epoch 33/100
#  - 95s - loss: 0.0406 - precision: 0.9892 - recall: 0.9853 - f1: 0.9872 - acc: 0.9884 - val_loss: 0.1991 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00033: val_loss did not improve from 0.00641
# Epoch 34/100
#  - 93s - loss: 0.0301 - precision: 0.9923 - recall: 0.9900 - f1: 0.9911 - acc: 0.9915 - val_loss: 0.3765 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00034: val_loss did not improve from 0.00641
# Epoch 35/100
#  - 90s - loss: 0.0294 - precision: 0.9915 - recall: 0.9877 - f1: 0.9895 - acc: 0.9884 - val_loss: 0.4871 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00035: val_loss did not improve from 0.00641
# Epoch 36/100
#  - 90s - loss: 0.0392 - precision: 0.9892 - recall: 0.9892 - f1: 0.9892 - acc: 0.9892 - val_loss: 2.1044 - val_precision: 0.5833 - val_recall: 0.5833 - val_f1: 0.5833 - val_acc: 0.5833
#
# Epoch 00036: val_loss did not improve from 0.00641
# Epoch 37/100
#  - 90s - loss: 0.0413 - precision: 0.9868 - recall: 0.9838 - f1: 0.9853 - acc: 0.9846 - val_loss: 2.7901 - val_precision: 0.4348 - val_recall: 0.4167 - val_f1: 0.4255 - val_acc: 0.4167
#
# Epoch 00037: val_loss did not improve from 0.00641
# Epoch 38/100
#  - 88s - loss: 0.0818 - precision: 0.9760 - recall: 0.9738 - f1: 0.9749 - acc: 0.9753 - val_loss: 0.6787 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00038: val_loss did not improve from 0.00641
# Epoch 39/100
#  - 90s - loss: 0.0746 - precision: 0.9752 - recall: 0.9738 - f1: 0.9745 - acc: 0.9738 - val_loss: 1.6099 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00039: val_loss did not improve from 0.00641
# Epoch 40/100
#  - 87s - loss: 0.0390 - precision: 0.9891 - recall: 0.9838 - f1: 0.9864 - acc: 0.9869 - val_loss: 0.3797 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00040: val_loss did not improve from 0.00641
# Epoch 41/100
#  - 88s - loss: 0.0263 - precision: 0.9915 - recall: 0.9892 - f1: 0.9903 - acc: 0.9900 - val_loss: 0.1231 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00041: val_loss did not improve from 0.00641
# Epoch 42/100
#  - 91s - loss: 0.0290 - precision: 0.9923 - recall: 0.9900 - f1: 0.9911 - acc: 0.9907 - val_loss: 0.5739 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00042: val_loss did not improve from 0.00641
# Epoch 43/100
#  - 90s - loss: 0.0366 - precision: 0.9868 - recall: 0.9853 - f1: 0.9861 - acc: 0.9861 - val_loss: 0.7831 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00043: val_loss did not improve from 0.00641
# Epoch 44/100
#  - 91s - loss: 0.0410 - precision: 0.9846 - recall: 0.9823 - f1: 0.9834 - acc: 0.9838 - val_loss: 0.7472 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00044: val_loss did not improve from 0.00641
# Epoch 45/100
#  - 91s - loss: 0.0631 - precision: 0.9797 - recall: 0.9753 - f1: 0.9774 - acc: 0.9769 - val_loss: 0.7584 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00045: val_loss did not improve from 0.00641
# Epoch 46/100
#  - 88s - loss: 0.0479 - precision: 0.9860 - recall: 0.9823 - f1: 0.9841 - acc: 0.9861 - val_loss: 4.9246e-04 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00046: val_loss improved from 0.00641 to 0.00049, saving model to models/BREASTNET_COVID19_FOLD_1.h5
# Epoch 47/100
#  - 91s - loss: 0.0483 - precision: 0.9860 - recall: 0.9853 - f1: 0.9857 - acc: 0.9853 - val_loss: 2.0298 - val_precision: 0.7143 - val_recall: 0.6250 - val_f1: 0.6667 - val_acc: 0.7500
#
# Epoch 00047: val_loss did not improve from 0.00049
# Epoch 48/100
#  - 92s - loss: 0.0290 - precision: 0.9931 - recall: 0.9900 - f1: 0.9915 - acc: 0.9915 - val_loss: 0.6288 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00048: val_loss did not improve from 0.00049
# Epoch 49/100
#  - 87s - loss: 0.0269 - precision: 0.9954 - recall: 0.9923 - f1: 0.9938 - acc: 0.9938 - val_loss: 1.1847 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00049: val_loss did not improve from 0.00049
# Epoch 50/100
#  - 85s - loss: 0.0206 - precision: 0.9938 - recall: 0.9907 - f1: 0.9923 - acc: 0.9915 - val_loss: 0.5953 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00050: val_loss did not improve from 0.00049
# Epoch 51/100
#  - 85s - loss: 0.0255 - precision: 0.9907 - recall: 0.9892 - f1: 0.9900 - acc: 0.9900 - val_loss: 0.7977 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00051: val_loss did not improve from 0.00049
# Epoch 52/100
#  - 84s - loss: 0.0466 - precision: 0.9892 - recall: 0.9869 - f1: 0.9880 - acc: 0.9869 - val_loss: 0.7781 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00052: val_loss did not improve from 0.00049
# Epoch 53/100
#  - 91s - loss: 0.0813 - precision: 0.9776 - recall: 0.9753 - f1: 0.9764 - acc: 0.9753 - val_loss: 0.7268 - val_precision: 0.9130 - val_recall: 0.8750 - val_f1: 0.8936 - val_acc: 0.9167
#
# Epoch 00053: val_loss did not improve from 0.00049
# Epoch 54/100
#  - 92s - loss: 0.0544 - precision: 0.9814 - recall: 0.9784 - f1: 0.9799 - acc: 0.9792 - val_loss: 2.9507 - val_precision: 0.6250 - val_recall: 0.6250 - val_f1: 0.6250 - val_acc: 0.6250
#
# Epoch 00054: val_loss did not improve from 0.00049
# Epoch 55/100
#  - 90s - loss: 0.0400 - precision: 0.9899 - recall: 0.9884 - f1: 0.9892 - acc: 0.9892 - val_loss: 0.9544 - val_precision: 0.9130 - val_recall: 0.8750 - val_f1: 0.8936 - val_acc: 0.9167
#
# Epoch 00055: val_loss did not improve from 0.00049
# Epoch 56/100
#  - 94s - loss: 0.0294 - precision: 0.9923 - recall: 0.9907 - f1: 0.9915 - acc: 0.9915 - val_loss: 1.5775 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00056: val_loss did not improve from 0.00049
# Epoch 57/100
#  - 89s - loss: 0.0308 - precision: 0.9931 - recall: 0.9915 - f1: 0.9923 - acc: 0.9915 - val_loss: 1.1899 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00057: val_loss did not improve from 0.00049
# Epoch 58/100
#  - 88s - loss: 0.0443 - precision: 0.9891 - recall: 0.9853 - f1: 0.9872 - acc: 0.9877 - val_loss: 0.9262 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00058: val_loss did not improve from 0.00049
# Epoch 59/100
#  - 87s - loss: 0.0597 - precision: 0.9776 - recall: 0.9753 - f1: 0.9764 - acc: 0.9776 - val_loss: 5.1841 - val_precision: 0.6667 - val_recall: 0.6667 - val_f1: 0.6667 - val_acc: 0.6667
#
# Epoch 00059: val_loss did not improve from 0.00049
# Epoch 60/100
#  - 87s - loss: 0.0788 - precision: 0.9776 - recall: 0.9738 - f1: 0.9757 - acc: 0.9738 - val_loss: 2.1813 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00060: val_loss did not improve from 0.00049
# Epoch 61/100
#  - 86s - loss: 0.0678 - precision: 0.9791 - recall: 0.9738 - f1: 0.9763 - acc: 0.9761 - val_loss: 1.1052 - val_precision: 0.7083 - val_recall: 0.7083 - val_f1: 0.7083 - val_acc: 0.7083
#
# Epoch 00061: val_loss did not improve from 0.00049
# Epoch 62/100
#  - 86s - loss: 0.0421 - precision: 0.9900 - recall: 0.9861 - f1: 0.9880 - acc: 0.9884 - val_loss: 1.0509 - val_precision: 0.8261 - val_recall: 0.7917 - val_f1: 0.8085 - val_acc: 0.7917
#
# Epoch 00062: val_loss did not improve from 0.00049
# Epoch 63/100
#  - 90s - loss: 0.0240 - precision: 0.9946 - recall: 0.9907 - f1: 0.9926 - acc: 0.9946 - val_loss: 1.2252 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
# Epoch 00063: val_loss did not improve from 0.00049
# Epoch 64/100
#  - 91s - loss: 0.0217 - precision: 0.9946 - recall: 0.9915 - f1: 0.9930 - acc: 0.9931 - val_loss: 0.0335 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00064: val_loss did not improve from 0.00049
# Epoch 65/100
#  - 90s - loss: 0.0250 - precision: 0.9938 - recall: 0.9938 - f1: 0.9938 - acc: 0.9938 - val_loss: 1.7379 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00065: val_loss did not improve from 0.00049
# Epoch 66/100
#  - 89s - loss: 0.0262 - precision: 0.9938 - recall: 0.9915 - f1: 0.9926 - acc: 0.9931 - val_loss: 0.0441 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00066: val_loss did not improve from 0.00049
# Epoch 67/100
#  - 89s - loss: 0.0293 - precision: 0.9946 - recall: 0.9900 - f1: 0.9922 - acc: 0.9900 - val_loss: 0.8470 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00067: val_loss did not improve from 0.00049
# Epoch 68/100
#  - 90s - loss: 0.0387 - precision: 0.9907 - recall: 0.9892 - f1: 0.9900 - acc: 0.9900 - val_loss: 0.9539 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00068: val_loss did not improve from 0.00049
# Epoch 69/100
#  - 94s - loss: 0.0410 - precision: 0.9868 - recall: 0.9846 - f1: 0.9857 - acc: 0.9853 - val_loss: 0.0109 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00069: val_loss did not improve from 0.00049
# Epoch 70/100
#  - 90s - loss: 0.0362 - precision: 0.9923 - recall: 0.9884 - f1: 0.9903 - acc: 0.9907 - val_loss: 1.4455 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00070: val_loss did not improve from 0.00049
# Epoch 71/100
#  - 90s - loss: 0.0375 - precision: 0.9877 - recall: 0.9861 - f1: 0.9869 - acc: 0.9869 - val_loss: 1.8575 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00071: val_loss did not improve from 0.00049
# Epoch 72/100
#  - 90s - loss: 0.0536 - precision: 0.9838 - recall: 0.9830 - f1: 0.9834 - acc: 0.9830 - val_loss: 0.3743 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00072: val_loss did not improve from 0.00049
# Epoch 73/100
#  - 90s - loss: 0.0362 - precision: 0.9899 - recall: 0.9884 - f1: 0.9892 - acc: 0.9892 - val_loss: 2.0392 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00073: val_loss did not improve from 0.00049
# Epoch 74/100
#  - 87s - loss: 0.0207 - precision: 0.9931 - recall: 0.9931 - f1: 0.9931 - acc: 0.9931 - val_loss: 1.1015 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00074: val_loss did not improve from 0.00049
# Epoch 75/100
#  - 91s - loss: 0.0212 - precision: 0.9961 - recall: 0.9938 - f1: 0.9949 - acc: 0.9946 - val_loss: 0.2142 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00075: val_loss did not improve from 0.00049
# Epoch 76/100
#  - 92s - loss: 0.0121 - precision: 0.9961 - recall: 0.9954 - f1: 0.9957 - acc: 0.9961 - val_loss: 0.8445 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00076: val_loss did not improve from 0.00049
# Epoch 77/100
#  - 93s - loss: 0.0171 - precision: 0.9954 - recall: 0.9946 - f1: 0.9950 - acc: 0.9954 - val_loss: 0.6913 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00077: val_loss did not improve from 0.00049
# Epoch 78/100
#  - 92s - loss: 0.0134 - precision: 0.9961 - recall: 0.9954 - f1: 0.9957 - acc: 0.9954 - val_loss: 1.3767 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00078: val_loss did not improve from 0.00049
# Epoch 79/100
#  - 91s - loss: 0.0241 - precision: 0.9938 - recall: 0.9931 - f1: 0.9934 - acc: 0.9931 - val_loss: 0.7839 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00079: val_loss did not improve from 0.00049
# Epoch 80/100
#  - 86s - loss: 0.0177 - precision: 0.9961 - recall: 0.9954 - f1: 0.9957 - acc: 0.9961 - val_loss: 0.8543 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00080: val_loss did not improve from 0.00049
# Epoch 81/100
#  - 85s - loss: 0.0128 - precision: 0.9961 - recall: 0.9954 - f1: 0.9957 - acc: 0.9961 - val_loss: 0.7150 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00081: val_loss did not improve from 0.00049
# Epoch 82/100
#  - 96s - loss: 0.0125 - precision: 0.9954 - recall: 0.9938 - f1: 0.9946 - acc: 0.9938 - val_loss: 0.2495 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00082: val_loss did not improve from 0.00049
# Epoch 83/100
# ...
#
# Epoch 00037: val_loss did not improve from 0.00791
# Epoch 38/100
#  - 89s - loss: 0.1080 - precision: 0.9707 - recall: 0.9628 - f1: 0.9666 - acc: 0.9680 - val_loss: 0.3663 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00038: val_loss did not improve from 0.00791
# Epoch 39/100
#  - 92s - loss: 0.0491 - precision: 0.9888 - recall: 0.9866 - f1: 0.9877 - acc: 0.9881 - val_loss: 0.0462 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00039: val_loss did not improve from 0.00791
# Epoch 40/100
#  - 88s - loss: 0.0441 - precision: 0.9881 - recall: 0.9866 - f1: 0.9873 - acc: 0.9866 - val_loss: 0.4948 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00040: val_loss did not improve from 0.00791
# Epoch 41/100
#  - 90s - loss: 0.0295 - precision: 0.9918 - recall: 0.9888 - f1: 0.9903 - acc: 0.9896 - val_loss: 0.0546 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00041: val_loss did not improve from 0.00791
# Epoch 42/100
#  - 88s - loss: 0.0323 - precision: 0.9903 - recall: 0.9881 - f1: 0.9892 - acc: 0.9888 - val_loss: 0.5377 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00042: val_loss did not improve from 0.00791
# Epoch 43/100
#  - 91s - loss: 0.0335 - precision: 0.9903 - recall: 0.9851 - f1: 0.9876 - acc: 0.9881 - val_loss: 1.1130 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00043: val_loss did not improve from 0.00791
# Epoch 44/100
#  - 87s - loss: 0.0515 - precision: 0.9851 - recall: 0.9814 - f1: 0.9832 - acc: 0.9836 - val_loss: 3.7211 - val_precision: 0.7083 - val_recall: 0.7083 - val_f1: 0.7083 - val_acc: 0.7083
#
# Epoch 00044: val_loss did not improve from 0.00791
# Epoch 45/100
#  - 89s - loss: 0.0601 - precision: 0.9829 - recall: 0.9814 - f1: 0.9821 - acc: 0.9821 - val_loss: 0.0070 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00045: val_loss improved from 0.00791 to 0.00699, saving model to models/BREASTNET_COVID19_FOLD_2.h5
# Epoch 46/100
#  - 91s - loss: 0.0923 - precision: 0.9724 - recall: 0.9665 - f1: 0.9694 - acc: 0.9702 - val_loss: 2.7224 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00046: val_loss did not improve from 0.00699
# Epoch 47/100
#  - 89s - loss: 0.0395 - precision: 0.9888 - recall: 0.9866 - f1: 0.9877 - acc: 0.9866 - val_loss: 3.1809 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00047: val_loss did not improve from 0.00699
# Epoch 48/100
#  - 92s - loss: 0.0307 - precision: 0.9918 - recall: 0.9874 - f1: 0.9895 - acc: 0.9903 - val_loss: 2.0183 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00048: val_loss did not improve from 0.00699
# Epoch 49/100
#  - 87s - loss: 0.0347 - precision: 0.9895 - recall: 0.9851 - f1: 0.9873 - acc: 0.9859 - val_loss: 0.3480 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00049: val_loss did not improve from 0.00699
# Epoch 50/100
#  - 89s - loss: 0.0268 - precision: 0.9918 - recall: 0.9896 - f1: 0.9907 - acc: 0.9903 - val_loss: 1.8263 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00050: val_loss did not improve from 0.00699
# Epoch 51/100
#  - 91s - loss: 0.0328 - precision: 0.9911 - recall: 0.9896 - f1: 0.9903 - acc: 0.9896 - val_loss: 0.4067 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00051: val_loss did not improve from 0.00699
# Epoch 52/100
#  - 89s - loss: 0.0388 - precision: 0.9925 - recall: 0.9896 - f1: 0.9910 - acc: 0.9911 - val_loss: 2.9324 - val_precision: 0.5417 - val_recall: 0.5417 - val_f1: 0.5417 - val_acc: 0.5417
#
# Epoch 00052: val_loss did not improve from 0.00699
# Epoch 53/100
#  - 90s - loss: 0.0295 - precision: 0.9926 - recall: 0.9896 - f1: 0.9910 - acc: 0.9926 - val_loss: 0.5790 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00053: val_loss did not improve from 0.00699
# Epoch 54/100
#  - 96s - loss: 0.0376 - precision: 0.9896 - recall: 0.9896 - f1: 0.9896 - acc: 0.9896 - val_loss: 1.3287 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00054: val_loss did not improve from 0.00699
# Epoch 55/100
#  - 91s - loss: 0.0201 - precision: 0.9940 - recall: 0.9933 - f1: 0.9937 - acc: 0.9940 - val_loss: 0.9387 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00055: val_loss did not improve from 0.00699
# Epoch 56/100
#  - 93s - loss: 0.0275 - precision: 0.9933 - recall: 0.9903 - f1: 0.9918 - acc: 0.9926 - val_loss: 2.4220 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00056: val_loss did not improve from 0.00699
# Epoch 57/100
#  - 92s - loss: 0.0147 - precision: 0.9963 - recall: 0.9955 - f1: 0.9959 - acc: 0.9963 - val_loss: 1.8616 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00057: val_loss did not improve from 0.00699
# Epoch 58/100
#  - 90s - loss: 0.0294 - precision: 0.9903 - recall: 0.9896 - f1: 0.9899 - acc: 0.9903 - val_loss: 0.3243 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00058: val_loss did not improve from 0.00699
# Epoch 59/100
#  - 87s - loss: 0.0330 - precision: 0.9888 - recall: 0.9888 - f1: 0.9888 - acc: 0.9888 - val_loss: 0.6108 - val_precision: 0.6667 - val_recall: 0.6667 - val_f1: 0.6667 - val_acc: 0.6667
#
# Epoch 00059: val_loss did not improve from 0.00699
# Epoch 60/100
#  - 91s - loss: 0.0421 - precision: 0.9866 - recall: 0.9859 - f1: 0.9862 - acc: 0.9866 - val_loss: 0.8218 - val_precision: 0.7273 - val_recall: 0.6667 - val_f1: 0.6957 - val_acc: 0.7083
#
# Epoch 00060: val_loss did not improve from 0.00699
# Epoch 61/100
#  - 88s - loss: 0.0387 - precision: 0.9881 - recall: 0.9866 - f1: 0.9873 - acc: 0.9874 - val_loss: 0.9693 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
# Epoch 00061: val_loss did not improve from 0.00699
# Epoch 62/100
#  - 96s - loss: 0.0177 - precision: 0.9940 - recall: 0.9933 - f1: 0.9937 - acc: 0.9933 - val_loss: 0.9189 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00062: val_loss did not improve from 0.00699
# Epoch 63/100
#  - 90s - loss: 0.0299 - precision: 0.9926 - recall: 0.9911 - f1: 0.9918 - acc: 0.9918 - val_loss: 0.4724 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00063: val_loss did not improve from 0.00699
# Epoch 64/100
#  - 91s - loss: 0.0207 - precision: 0.9948 - recall: 0.9933 - f1: 0.9940 - acc: 0.9940 - val_loss: 0.0205 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00064: val_loss did not improve from 0.00699
# Epoch 65/100
#  - 88s - loss: 0.0158 - precision: 0.9970 - recall: 0.9963 - f1: 0.9966 - acc: 0.9970 - val_loss: 0.6717 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00065: val_loss did not improve from 0.00699
# Epoch 66/100
#  - 90s - loss: 0.0334 - precision: 0.9933 - recall: 0.9926 - f1: 0.9929 - acc: 0.9926 - val_loss: 2.3596 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00066: val_loss did not improve from 0.00699
# Epoch 67/100
#  - 89s - loss: 0.0658 - precision: 0.9821 - recall: 0.9814 - f1: 0.9818 - acc: 0.9814 - val_loss: 6.0443 - val_precision: 0.6250 - val_recall: 0.6250 - val_f1: 0.6250 - val_acc: 0.6250
#
# Epoch 00067: val_loss did not improve from 0.00699
# Epoch 68/100
#  - 90s - loss: 0.0370 - precision: 0.9918 - recall: 0.9874 - f1: 0.9895 - acc: 0.9888 - val_loss: 2.3785 - val_precision: 0.6667 - val_recall: 0.6667 - val_f1: 0.6667 - val_acc: 0.6667
#
# Epoch 00068: val_loss did not improve from 0.00699
# Epoch 69/100
#  - 89s - loss: 0.0280 - precision: 0.9933 - recall: 0.9926 - f1: 0.9929 - acc: 0.9926 - val_loss: 1.2752 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00069: val_loss did not improve from 0.00699
# Epoch 70/100
#  - 87s - loss: 0.0209 - precision: 0.9933 - recall: 0.9911 - f1: 0.9922 - acc: 0.9911 - val_loss: 2.7635 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00070: val_loss did not improve from 0.00699
# Epoch 71/100
#  - 84s - loss: 0.0432 - precision: 0.9874 - recall: 0.9859 - f1: 0.9866 - acc: 0.9874 - val_loss: 2.6185 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00071: val_loss did not improve from 0.00699
# Epoch 72/100
#  - 93s - loss: 0.0409 - precision: 0.9859 - recall: 0.9851 - f1: 0.9855 - acc: 0.9859 - val_loss: 0.4971 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00072: val_loss did not improve from 0.00699
# Epoch 73/100
#  - 91s - loss: 0.0430 - precision: 0.9873 - recall: 0.9866 - f1: 0.9870 - acc: 0.9874 - val_loss: 1.2053 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00073: val_loss did not improve from 0.00699
# Epoch 74/100
#  - 90s - loss: 0.0347 - precision: 0.9911 - recall: 0.9903 - f1: 0.9907 - acc: 0.9911 - val_loss: 0.7975 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00074: val_loss did not improve from 0.00699
# Epoch 75/100
#  - 87s - loss: 0.0266 - precision: 0.9940 - recall: 0.9926 - f1: 0.9933 - acc: 0.9940 - val_loss: 0.4709 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00075: val_loss did not improve from 0.00699
# Epoch 76/100
#  - 90s - loss: 0.0141 - precision: 0.9970 - recall: 0.9963 - f1: 0.9966 - acc: 0.9963 - val_loss: 0.5159 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00076: val_loss did not improve from 0.00699
# Epoch 77/100
#  - 89s - loss: 0.0119 - precision: 0.9970 - recall: 0.9963 - f1: 0.9966 - acc: 0.9970 - val_loss: 1.1538 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00077: val_loss did not improve from 0.00699
# Epoch 78/100
#  - 91s - loss: 0.0116 - precision: 0.9978 - recall: 0.9970 - f1: 0.9974 - acc: 0.9978 - val_loss: 1.6736 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00078: val_loss did not improve from 0.00699
# Epoch 79/100
#  - 91s - loss: 0.0176 - precision: 0.9955 - recall: 0.9940 - f1: 0.9948 - acc: 0.9955 - val_loss: 2.2785 - val_precision: 0.7083 - val_recall: 0.7083 - val_f1: 0.7083 - val_acc: 0.7083
#
# Epoch 00079: val_loss did not improve from 0.00699
# Epoch 80/100
#  - 91s - loss: 0.0122 - precision: 0.9970 - recall: 0.9955 - f1: 0.9963 - acc: 0.9955 - val_loss: 1.7996 - val_precision: 0.7083 - val_recall: 0.7083 - val_f1: 0.7083 - val_acc: 0.7083
#
# Epoch 00080: val_loss did not improve from 0.00699
# Epoch 81/100
#  - 89s - loss: 0.0157 - precision: 0.9955 - recall: 0.9933 - f1: 0.9944 - acc: 0.9940 - val_loss: 1.0577 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00081: val_loss did not improve from 0.00699
# Epoch 82/100
#  - 93s - loss: 0.0206 - precision: 0.9948 - recall: 0.9926 - f1: 0.9937 - acc: 0.9933 - val_loss: 1.3426 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00082: val_loss did not improve from 0.00699
# Epoch 83/100
#  - 88s - loss: 0.0345 - precision: 0.9911 - recall: 0.9911 - f1: 0.9911 - acc: 0.9911 - val_loss: 0.6582 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00083: val_loss did not improve from 0.00699
# Epoch 84/100
#  - 90s - loss: 0.0392 - precision: 0.9865 - recall: 0.9844 - f1: 0.9854 - acc: 0.9866 - val_loss: 1.3440 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00084: val_loss did not improve from 0.00699
# Epoch 85/100
#  - 92s - loss: 0.0509 - precision: 0.9872 - recall: 0.9836 - f1: 0.9854 - acc: 0.9851 - val_loss: 0.0661 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00085: val_loss did not improve from 0.00699
# Epoch 86/100
#  - 91s - loss: 0.0590 - precision: 0.9807 - recall: 0.9799 - f1: 0.9803 - acc: 0.9799 - val_loss: 2.0007 - val_precision: 0.6667 - val_recall: 0.6667 - val_f1: 0.6667 - val_acc: 0.6667
#
# Epoch 00086: val_loss did not improve from 0.00699
# Epoch 87/100
#  - 91s - loss: 0.0364 - precision: 0.9911 - recall: 0.9903 - f1: 0.9907 - acc: 0.9903 - val_loss: 0.9079 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00087: val_loss did not improve from 0.00699
# Epoch 88/100
#  - 87s - loss: 0.0364 - precision: 0.9933 - recall: 0.9911 - f1: 0.9921 - acc: 0.9926 - val_loss: 4.6291 - val_precision: 0.7083 - val_recall: 0.7083 - val_f1: 0.7083 - val_acc: 0.7083
#
# Epoch 00088: val_loss did not improve from 0.00699
# Epoch 89/100
#  - 86s - loss: 0.0200 - precision: 0.9955 - recall: 0.9948 - f1: 0.9952 - acc: 0.9948 - val_loss: 0.1506 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00089: val_loss did not improve from 0.00699
# Epoch 90/100
#  - 94s - loss: 0.0114 - precision: 0.9955 - recall: 0.9948 - f1: 0.9952 - acc: 0.9948 - val_loss: 1.7457 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00090: val_loss did not improve from 0.00699
# Epoch 91/100
#  - 91s - loss: 0.0138 - precision: 0.9963 - recall: 0.9955 - f1: 0.9959 - acc: 0.9955 - val_loss: 0.7245 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00091: val_loss did not improve from 0.00699
# Epoch 92/100
#  - 87s - loss: 0.0091 - precision: 0.9985 - recall: 0.9970 - f1: 0.9978 - acc: 0.9985 - val_loss: 3.2341 - val_precision: 0.6250 - val_recall: 0.6250 - val_f1: 0.6250 - val_acc: 0.6250
#
# Epoch 00092: val_loss did not improve from 0.00699
# Epoch 93/100
#  - 91s - loss: 0.0139 - precision: 0.9948 - recall: 0.9933 - f1: 0.9940 - acc: 0.9933 - val_loss: 2.1163 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1: 0.7500 - val_acc: 0.7500
#
# Epoch 00093: val_loss did not improve from 0.00699
# Epoch 94/100
#  - 88s - loss: 0.0180 - precision: 0.9918 - recall: 0.9918 - f1: 0.9918 - acc: 0.9918 - val_loss: 0.0994 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
# Epoch 00094: val_loss did not improve from 0.00699
# Epoch 95/100
#  - 90s - loss: 0.0071 - precision: 1.0000 - recall: 0.9993 - f1: 0.9996 - acc: 0.9993 - val_loss: 1.0685 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00095: val_loss did not improve from 0.00699
# Epoch 96/100
#  - 92s - loss: 0.0181 - precision: 0.9933 - recall: 0.9926 - f1: 0.9929 - acc: 0.9926 - val_loss: 0.8812 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00096: val_loss did not improve from 0.00699
# Epoch 97/100
#  - 92s - loss: 0.0292 - precision: 0.9926 - recall: 0.9926 - f1: 0.9926 - acc: 0.9926 - val_loss: 1.1954 - val_precision: 0.8261 - val_recall: 0.7917 - val_f1: 0.8085 - val_acc: 0.7917
#
# Epoch 00097: val_loss did not improve from 0.00699
# Epoch 98/100
#  - 87s - loss: 0.0386 - precision: 0.9866 - recall: 0.9836 - f1: 0.9851 - acc: 0.9851 - val_loss: 0.6226 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00098: val_loss did not improve from 0.00699
# Epoch 99/100
#  - 86s - loss: 0.0681 - precision: 0.9783 - recall: 0.9762 - f1: 0.9772 - acc: 0.9777 - val_loss: 0.4900 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00099: val_loss did not improve from 0.00699
# Epoch 100/100
#  - 91s - loss: 0.0678 - precision: 0.9834 - recall: 0.9740 - f1: 0.9785 - acc: 0.9799 - val_loss: 0.7356 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00100: val_loss did not improve from 0.00699

# %% [markdown]
# ### Testing

# %%
gen = COVID19_DATASET(metadata, SHAPE, BATCH_SIZE, range(1), BASE_DIR, SEED, TRAIN_TEST_RATIO, augment=False).split_train_test("test")
                       
x_test = np.zeros((len(gen[0]),)+SHAPE, dtype=np.float32)
y_test = np.zeros((len(gen[1]), len(sample_dataset.unique_labels)), dtype=np.float32)

for ix, path in tqdm(enumerate(gen[0])):
    img = cv2.imread(path)
    img = cv2.resize(img, SHAPE[:2])
    img = np.divide(img,255)

    label = gen[1][ix]

    x_test[ix] = img
    y_test[ix] = label
# Out:
# 36it [00:01, 34.47it/s]

# %%
# Threshold predictions with THRESH_VAL
def threshold_arr(array):
    # Get all value from array
    # Compare calue with THRESH_VAL 
    # IF value >= THRESH_VAL. round to 1
    # ELSE. round to 0
    new_arr = []
    for ix, val in enumerate(array):
        loc = np.array(val).argmax(axis=0)
        k = list(np.zeros((len(val)), dtype=np.float32))
        k[loc]=1
        new_arr.append(k)
        
    return np.array(new_arr, dtype=np.float32)

# %% [markdown]
# ### Get Results

# %%
models = []
scores = []
for i in range(N_SPLITS):
    model = load_model("models/BREASTNET_COVID19_FOLD_{}.h5".format(i), custom_objects={'f1': f1, 'precision': precision, 'recall': recall})
    score = model.evaluate(x_test, y_test, verbose=0)
    print(score)
    scores.append(score[-1])
    models.append(model)
# Out:
# W0316 14:41:44.059517 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0316 14:41:44.064520 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0316 14:41:44.151547 19208 deprecation.py:323] From C:\Users\pc\Anaconda3\envs\dl\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0316 14:41:44.687548 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0316 14:41:45.008543 19208 module_wrapper.py:139] From C:\Users\pc\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# [1.324776440858841, 0.8333333333333334, 0.8333333333333334, 0.8333332737286886, 0.8333333333333334]
# [1.653943591647678, 0.8611111111111112, 0.8611111111111112, 0.8611110515064664, 0.8611111111111112]
# [1.162466337852594, 0.7706093258327908, 0.75, 0.7601410547892252, 0.7777777777777778]

# %%
best_model_idx = np.array(scores).argmax()
best_model = models[best_model_idx]
print(best_model_idx)
# Out:
# 1

# %%
y_preds = threshold_arr(best_model.predict(x_test, verbose=0))

# %%
results = precision_recall_fscore_support(y_test, y_preds, average='micro')
acc = accuracy_score(y_test, y_preds)
roc_auc = roc_auc_score(y_test, y_preds, average='micro')

print("ROC_AUC: {}, Accuracy: {}, F1_Score: {}, Precision: {}, Recall: {}".format(roc_auc, acc, results[2], results[0], results[1]))
print("\n")
print(classification_report(y_test, y_preds))
print("\n")
cnf_matrix = confusion_matrix(y_test.argmax(axis=1), y_preds.argmax(axis=1))

plot_confusion_matrix(cm           = cnf_matrix, 
                      desc         = f"{best_model_idx+1}. FOLD (BEST) - Multiclass",
                      normalize    = False,
                      target_names = sample_dataset.unique_labels,
                      title        = "Confusion Matrix")
# Out:
# ROC_AUC: 0.9166666666666666, Accuracy: 0.8611111111111112, F1_Score: 0.8611111111111112, Precision: 0.8611111111111112, Recall: 0.8611111111111112
#
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.85      1.00      0.92        28
#            2       0.00      0.00      0.00         1
#            3       0.00      0.00      0.00         1
#            4       1.00      1.00      1.00         3
#            5       0.00      0.00      0.00         2
#
#    micro avg       0.86      0.86      0.86        36
#    macro avg       0.31      0.33      0.32        36
# weighted avg       0.74      0.86      0.80        36
#  samples avg       0.86      0.86      0.86        36

# %% [markdown]
# ### BREASTNET-COVID-19 Convert Predictions to Binary Classification (COVID-19 or NOT)

# %%
covid_ord = np.where(sample_dataset.unique_labels=='COVID-19')[0][0]

# %%
bin_labels = []
for pred in y_test:
    if pred.argmax() == covid_ord:
        binary_label = 1
    else:
        binary_label = 0
    bin_labels.append(binary_label)
    
bin_preds = []
for pred in y_preds:
    if pred.argmax() == covid_ord:
        binary_label = 1
    else:
        binary_label = 0
    bin_preds.append(binary_label)

# %%
results = precision_recall_fscore_support(bin_labels, bin_preds, average='binary')
acc = accuracy_score(bin_labels, bin_preds)
roc_auc = roc_auc_score(bin_labels, bin_preds)

print("ROC_AUC: {}, Accuracy: {}, F1_Score: {}, Precision: {}, Recall: {}".format(roc_auc, acc, results[2], results[0], results[1]))
print("\n")
print(classification_report(bin_labels, bin_preds))
print("\n")
cnf_matrix = confusion_matrix(bin_labels, bin_preds)

plot_confusion_matrix(cm           = cnf_matrix, 
                      desc         = f"{best_model_idx+1}. FOLD - Binary",
                      normalize    = False,
                      target_names = ['Other','COVID-19'],
                      title        = "Confusion Matrix")
# Out:
# ROC_AUC: 0.6875, Accuracy: 0.8611111111111112, F1_Score: 0.9180327868852458, Precision: 0.8484848484848485, Recall: 1.0
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.38      0.55         8
#            1       0.85      1.00      0.92        28
#
#     accuracy                           0.86        36
#    macro avg       0.92      0.69      0.73        36
# weighted avg       0.88      0.86      0.84        36

# %% [markdown]
# ### Basic Speed Test on _NVIDIA_GTX_1070_

# %%
import time
for i in range(5): 
    img = cv2.imread(os.path.join(BASE_DIR,"images/01E392EE-69F9-4E33-BFCE-E5C968654078.jpeg"))
    x = cv2.resize(img, SHAPE[:2])
    x = np.divide(x, 255)
    x = x.reshape((1,) + x.shape) 
    start = time.time()
    prediction = best_model.predict(x, batch_size=1)
    finish = time.time()
    print(threshold_arr(prediction))
    print((finish-start)*1000,"ms")
    print("***")
# Out:
# [[0. 1. 0. 0. 0. 0.]]
# 213.03939819335938 ms
# ***
# [[0. 1. 0. 0. 0. 0.]]
# 7.042169570922852 ms
# ***
# [[0. 1. 0. 0. 0. 0.]]
# 7.9708099365234375 ms
# ***
# [[0. 1. 0. 0. 0. 0.]]
# 8.000612258911133 ms
# ***
# [[0. 1. 0. 0. 0. 0.]]
# 7.96055793762207 ms
# ***
